# %% [markdown]
# <center><h1>Using <code>select()</code> Function in dplyr</h1></center>

# %% [markdown]
# # 1. Using `select()` to Extract Columns
#   - Recall that `filter()` can be used to filter rows
#   - Similarly, `select()` is used to select columns
#   - These functions can be "chained"

# %% [markdown]
# ## 1.1 Example of `select()`

# %%
library(dplyr)

arrests <- read.csv("data/pvd_arrests_2020-10-03.csv")
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
arrests_subset <- arrests %>% 
    select(arrestee_id, age, gender, statute_desc)

head(arrests_subset)
# Out:
#   arrestee_id             age gender
# 1 pvd2218242150382148273  37  Male
# 2 pvd15166785558364246202 25
# 3 pvd3142917706201385905  34  Female
# 4 pvd3142917706201385905  34  Female
# 5 pvd460449304532374599   18  Female
# 6 pvd460449304532374599   18  Female
#   statute_desc
# 1
# 2 Driving after Denial, Suspension or Revocation of License
# 3 RESISTING LEGAL OR ILLEGAL ARREST
# 4 DISORDERLY CONDUCT
# 5 RESISTING LEGAL OR ILLEGAL ARREST
# 6 DISORDERLY CONDUCT

# %% [markdown]
# ### 1.1.1 Comparing `select()` to `[, ]` notation

# %%
# dplyr example
arrests %>% 
    select(arrestee_id, age, gender, statute_desc)


# equivalent in "base" R example
cols <- c("arrestee_id", "age", "gender", "statute_desc")

arrests[, cols]
# Out:
#      arrestee_id             age gender
# 1    pvd2218242150382148273  37  Male
# 2    pvd15166785558364246202 25
# 3    pvd3142917706201385905  34  Female
# 4    pvd3142917706201385905  34  Female
# 5    pvd460449304532374599   18  Female
# 6    pvd460449304532374599   18  Female
# 7    pvd460449304532374599   18  Female
# 8    pvd6431558757894418021  28  Male
# 9    pvd6431558757894418021  28  Male
# 10   pvd6431558757894418021  28  Male
# 11   pvd15614289459563584867 22  Male
# 12   pvd900460037611487829   19  Male
# 13   pvd900460037611487829   19  Male
# 14   pvd1675234703933765967  23  Male
# 15   pvd1675234703933765967  23  Male
# 16   pvd8555094992612905738  45  Female
# 17   pvd8555094992612905738  45  Female
# 18   pvd17953747948212880432 20  Male
# 19   pvd15100522507516509426 47  Male
# 20   pvd1784400650677464818  30  Male
# 21   pvd1784400650677464818  30  Male
# 22   pvd17906628124789383577 54  Male
# 23   pvd2709931773722136485  39  Male
# 24   pvd3024232238010666153  21  Male
# 25   pvd5436004350740110700  40  Male
# 26   pvd5436004350740110700  40  Male
# 27   pvd18360527540285642844 59  Male
# 28   pvd18360527540285642844 59  Male
# 29   pvd6329853531447301575  38  Male
# 30   pvd4717540273846557288  31  Female
# ⋮    ⋮                       ⋮   ⋮
# 8726 pvd6847437265855082531  24  Female
# 8727 pvd6847437265855082531  24  Female
# 8728 pvd10486073748894772221 44  Male
# 8729 pvd14228342987261766892 35  Male
# 8730 pvd5257435183320846711  51  Male
# 8731 pvd5257435183320846711  51  Male
# 8732 pvd6014105176016998190  32  Male
# 8733 pvd16628535577915270026 25  Male
# 8734 pvd16628535577915270026 25  Male
# 8735 pvd7732905157072162140  28  Female
# 8736 pvd7732905157072162140  28  Female
# 8737 pvd7732905157072162140  28  Female
# 8738 pvd14783764350884014595 32  Male
# 8739 pvd467817857219686623   55  Male
# 8740 pvd9295729193531288284  55  Female
# 8741 pvd12212629709488901378 40  Male
# 8742 pvd4464707333206490510  24  Male
# 8743 pvd4464707333206490510  24  Male
# 8744 pvd6155618112432892995  72  Male
# 8745 pvd8046681516085598213  21  Male
# 8746 pvd8046681516085598213  21  Male
# 8747 pvd8046681516085598213  21  Male
# 8748 pvd8046681516085598213  21  Male
# 8749 pvd8046681516085598213  21  Male
# 8750 pvd13478136167689373662 50  Male
# 8751 pvd15638788339600544418 29  Male
# 8752 pvd7076185679870331431  33  Female
# 8753 pvd17011494258935977890 39  Male
# 8754 pvd504225440707713502   24  Male
# 8755 pvd13901373320918968650 51  Male
#      statute_desc
# 1
# 2    Driving after Denial, Suspension or Revocation of License
# 3    RESISTING LEGAL OR ILLEGAL ARREST
# 4    DISORDERLY CONDUCT
# 5    RESISTING LEGAL OR ILLEGAL ARREST
# 6    DISORDERLY CONDUCT
# 7    OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 8    Chemical Test Refusal
# 9    Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 10   Driving after Denial, Suspension or Revocation of License
# 11   DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 12   Reckless Driving, Drag Racing - Attempting to Elude
# 13   Driving after Denial, Suspension or Revocation of License
# 14   RESISTING LEGAL OR ILLEGAL ARREST
# 15   OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 16   VANDALISM/MALICIOUS INJURY TO PROPERTY
# 17   Disorderly and Indecent Conduct B - Loud Noise
# 18   DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 19   Driving after Denial, Suspension or Revocation of License
# 20   MANUFACTURE/POSS/DELIVER SCH III/IV
# 21   MANUFAC/POSS/DELIVER SCH 1/II
# 22   Driving after Denial, Suspension or Revocation of License
# 23
# 24   SIMPLE ASSAULT OR BATTERY
# 25   CONTROLLED SUBSTANCE CONSPIRACY
# 26   MANUFAC/POSS/DELIVER SCH 1/II
# 27   CONTROLLED SUBSTANCE CONSPIRACY
# 28   MANUFAC/POSS/DELIVER SCH 1/II
# 29
# 30   BENCH WARRANT ISSUED FROM SUPERIOR COURT
# ⋮    ⋮
# 8726 Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 8727 Driving after Denial, Suspension or Revocation of License
# 8728 NULL
# 8729 ASSAULT OF POLICE OFFICERS AND OTHER OFFICIALS - MINOR INJURY
# 8730 WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE
# 8731 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 8732 DOMESTIC-DISORDERLY CONDUCT
# 8733 Chemical Test Refusal
# 8734 Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 8735 BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT
# 8736 POSSESSION OF SCHEDULE I II III
# 8737 BENCH WARRANT ISSUED FROM SUPERIOR COURT
# 8738 NULL
# 8739 NULL
# 8740 DOMESTIC-DISORDERLY CONDUCT
# 8741 VIOLATION OF PROTECTIVE ORDER
# 8742 Possession of Stolen Vehicle or Parts
# 8743 Driving after Denial, Revocation or Suspension for Misd.
# 8744 DISORDERLY CONDUCT
# 8745 DOMESTIC-FELONY ASSAULT
# 8746 WEAPONS OTHER THAN FIREARMS PROHIBITED
# 8747 DOMESTIC-DISORDERLY CONDUCT
# 8748 DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 8749 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 8750 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE
# 8751 Driving after Denial, Suspension or Revocation of License
# 8752 NULL
# 8753 NULL
# 8754 Driving after Denial, Suspension or Revocation of License
# 8755 DISORDERLY CONDUCT
#      arrestee_id             age gender
# 1    pvd2218242150382148273  37  Male
# 2    pvd15166785558364246202 25
# 3    pvd3142917706201385905  34  Female
# 4    pvd3142917706201385905  34  Female
# 5    pvd460449304532374599   18  Female
# 6    pvd460449304532374599   18  Female
# 7    pvd460449304532374599   18  Female
# 8    pvd6431558757894418021  28  Male
# 9    pvd6431558757894418021  28  Male
# 10   pvd6431558757894418021  28  Male
# 11   pvd15614289459563584867 22  Male
# 12   pvd900460037611487829   19  Male
# 13   pvd900460037611487829   19  Male
# 14   pvd1675234703933765967  23  Male
# 15   pvd1675234703933765967  23  Male
# 16   pvd8555094992612905738  45  Female
# 17   pvd8555094992612905738  45  Female
# 18   pvd17953747948212880432 20  Male
# 19   pvd15100522507516509426 47  Male
# 20   pvd1784400650677464818  30  Male
# 21   pvd1784400650677464818  30  Male
# 22   pvd17906628124789383577 54  Male
# 23   pvd2709931773722136485  39  Male
# 24   pvd3024232238010666153  21  Male
# 25   pvd5436004350740110700  40  Male
# 26   pvd5436004350740110700  40  Male
# 27   pvd18360527540285642844 59  Male
# 28   pvd18360527540285642844 59  Male
# 29   pvd6329853531447301575  38  Male
# 30   pvd4717540273846557288  31  Female
# ⋮    ⋮                       ⋮   ⋮
# 8726 pvd6847437265855082531  24  Female
# 8727 pvd6847437265855082531  24  Female
# 8728 pvd10486073748894772221 44  Male
# 8729 pvd14228342987261766892 35  Male
# 8730 pvd5257435183320846711  51  Male
# 8731 pvd5257435183320846711  51  Male
# 8732 pvd6014105176016998190  32  Male
# 8733 pvd16628535577915270026 25  Male
# 8734 pvd16628535577915270026 25  Male
# 8735 pvd7732905157072162140  28  Female
# 8736 pvd7732905157072162140  28  Female
# 8737 pvd7732905157072162140  28  Female
# 8738 pvd14783764350884014595 32  Male
# 8739 pvd467817857219686623   55  Male
# 8740 pvd9295729193531288284  55  Female
# 8741 pvd12212629709488901378 40  Male
# 8742 pvd4464707333206490510  24  Male
# 8743 pvd4464707333206490510  24  Male
# 8744 pvd6155618112432892995  72  Male
# 8745 pvd8046681516085598213  21  Male
# 8746 pvd8046681516085598213  21  Male
# 8747 pvd8046681516085598213  21  Male
# 8748 pvd8046681516085598213  21  Male
# 8749 pvd8046681516085598213  21  Male
# 8750 pvd13478136167689373662 50  Male
# 8751 pvd15638788339600544418 29  Male
# 8752 pvd7076185679870331431  33  Female
# 8753 pvd17011494258935977890 39  Male
# 8754 pvd504225440707713502   24  Male
# 8755 pvd13901373320918968650 51  Male
#      statute_desc
# 1
# 2    Driving after Denial, Suspension or Revocation of License
# 3    RESISTING LEGAL OR ILLEGAL ARREST
# 4    DISORDERLY CONDUCT
# 5    RESISTING LEGAL OR ILLEGAL ARREST
# 6    DISORDERLY CONDUCT
# 7    OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 8    Chemical Test Refusal
# 9    Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 10   Driving after Denial, Suspension or Revocation of License
# 11   DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 12   Reckless Driving, Drag Racing - Attempting to Elude
# 13   Driving after Denial, Suspension or Revocation of License
# 14   RESISTING LEGAL OR ILLEGAL ARREST
# 15   OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 16   VANDALISM/MALICIOUS INJURY TO PROPERTY
# 17   Disorderly and Indecent Conduct B - Loud Noise
# 18   DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 19   Driving after Denial, Suspension or Revocation of License
# 20   MANUFACTURE/POSS/DELIVER SCH III/IV
# 21   MANUFAC/POSS/DELIVER SCH 1/II
# 22   Driving after Denial, Suspension or Revocation of License
# 23
# 24   SIMPLE ASSAULT OR BATTERY
# 25   CONTROLLED SUBSTANCE CONSPIRACY
# 26   MANUFAC/POSS/DELIVER SCH 1/II
# 27   CONTROLLED SUBSTANCE CONSPIRACY
# 28   MANUFAC/POSS/DELIVER SCH 1/II
# 29
# 30   BENCH WARRANT ISSUED FROM SUPERIOR COURT
# ⋮    ⋮
# 8726 Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 8727 Driving after Denial, Suspension or Revocation of License
# 8728 NULL
# 8729 ASSAULT OF POLICE OFFICERS AND OTHER OFFICIALS - MINOR INJURY
# 8730 WARRANT OF ARREST ON AFFIDAVIT - ALL OTH OFFENSE
# 8731 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 8732 DOMESTIC-DISORDERLY CONDUCT
# 8733 Chemical Test Refusal
# 8734 Driving Under the Influence of Liqour or Drugs (=>.08<.1)
# 8735 BENCH WARRANT ISSUED FROM 6TH DISTRICT COURT
# 8736 POSSESSION OF SCHEDULE I II III
# 8737 BENCH WARRANT ISSUED FROM SUPERIOR COURT
# 8738 NULL
# 8739 NULL
# 8740 DOMESTIC-DISORDERLY CONDUCT
# 8741 VIOLATION OF PROTECTIVE ORDER
# 8742 Possession of Stolen Vehicle or Parts
# 8743 Driving after Denial, Revocation or Suspension for Misd.
# 8744 DISORDERLY CONDUCT
# 8745 DOMESTIC-FELONY ASSAULT
# 8746 WEAPONS OTHER THAN FIREARMS PROHIBITED
# 8747 DOMESTIC-DISORDERLY CONDUCT
# 8748 DOMESTIC-VANDALISM/MALICIOUS INJURY TO PROP
# 8749 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 8750 FELONY ASSAULT/ DANG. WEAPON OR SUBSTANCE
# 8751 Driving after Denial, Suspension or Revocation of License
# 8752 NULL
# 8753 NULL
# 8754 Driving after Denial, Suspension or Revocation of License
# 8755 DISORDERLY CONDUCT

# %% [markdown]
# ## 1.2 Example of `select()` (cont.)

# %%
arrests_vio <- arrests %>%
    select(
        arrestee_id,
        age,
        gender,
        statute_desc
    )

# %%
head(arrests_vio)           # see first few lines of new dataframe
# Out:
#   arrestee_id             age gender
# 1 pvd2218242150382148273  37  Male
# 2 pvd15166785558364246202 25
# 3 pvd3142917706201385905  34  Female
# 4 pvd3142917706201385905  34  Female
# 5 pvd460449304532374599   18  Female
# 6 pvd460449304532374599   18  Female
#   statute_desc
# 1
# 2 Driving after Denial, Suspension or Revocation of License
# 3 RESISTING LEGAL OR ILLEGAL ARREST
# 4 DISORDERLY CONDUCT
# 5 RESISTING LEGAL OR ILLEGAL ARREST
# 6 DISORDERLY CONDUCT

# %% [markdown]
# # 2. Chaining _dplyr_ Operators
#   - One key reason for _dplyr_ popularity
#   - _dplyr_ verbs/functions are "composable"
#     + $(f \circ g)(x) == f(g(x))$

# %%
female_vio <- arrests %>%
    filter(gender == "Female") %>%
    select(arrestee_id, age, gender, statute_desc)

head(female_vio)
# Out:
#   arrestee_id            age gender statute_desc
# 1 pvd3142917706201385905 34  Female RESISTING LEGAL OR ILLEGAL ARREST
# 2 pvd3142917706201385905 34  Female DISORDERLY CONDUCT
# 3 pvd460449304532374599  18  Female RESISTING LEGAL OR ILLEGAL ARREST
# 4 pvd460449304532374599  18  Female DISORDERLY CONDUCT
# 5 pvd460449304532374599  18  Female OBSTRUCTING OFFICER IN EXECUTION OF DUTY
# 6 pvd8555094992612905738 45  Female VANDALISM/MALICIOUS INJURY TO PROPERTY

# %% [markdown]
# ## 2.1 More Chaining

# %%
female_midage <- arrests %>%
    filter(
        gender == "Female",
        age > 45,
        statute_desc != ""
    ) %>%
    select(
        arrestee_id, 
        age, 
        gender,
        statute_desc
    ) %>%
    arrange(
        arrestee_id
    )

head(female_midage)
# Out:
#   arrestee_id             age gender
# 1 pvd10124563078769507165 52  Female
# 2 pvd10764271506246443138 53  Female
# 3 pvd10857153000728613606 54  Female
# 4 pvd10879521477909738425 48  Female
# 5 pvd10909858543687069510 49  Female
# 6 pvd11014001617297730559 47  Female
#   statute_desc
# 1 BENCH WARRANT ISSUED FROM SUPERIOR COURT
# 2 DOMESTIC-SIMPLE ASSAULT/BATTERY
# 3 Driving after Denial, Suspension or Revocation of License
# 4 DISORDERLY CONDUCT
# 5 NULL
# 6 Driving after Denial, Suspension or Revocation of License
